# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('energydata_complete.csv')

# %%
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
column_names = {
    'T1': 'Temp_kit', 'RH_1' : 'Humidity_kit', 'T2': 'Temp_living', 
    'RH_2' : 'Humidity_living', 'T3' :'Temp_laundry', 
    'RH_3' :'Humidity_laundry', 'T4':'Temp_office', 'RH_4': 'Humidity_office',
    'T5' :'Temp_bath', 'RH_5' :'Humidity_bath', 'T6':'Temp_outbuilding', 
    'RH_6' :'Humidity_outbuilding', 'T7':'Temp_iron', 'RH_7':'Humidity_ironing',
    'T8':'Temp_teenager', 'RH_8':'Humidity_teenager', 'T9':'Temp_parents', 
    'RH_9':'Humidity_parents','T_out':'Temp_outside', 'Press_mm_hg' :'press_mm_hg', 
    'RH_out':'Humidity_outside', 'Wind speed': 'wind_speed', 
    'Visibility': 'visibility', 'Tdewpoint': 'Tdew_point','rv1':'rv_1',
    'rv2':'rv_2', 
}

# %%
df = df.rename(columns = column_names)

# %%
df.head()
# Out:
#                   date  Appliances  lights  Temp_kit  Humidity_kit  \
# 0  2016-01-11 17:00:00          60      30     19.89     47.596667
# 1  2016-01-11 17:10:00          60      30     19.89     46.693333
# 2  2016-01-11 17:20:00          50      30     19.89     46.300000
# 3  2016-01-11 17:30:00          50      40     19.89     46.066667
# 4  2016-01-11 17:40:00          60      40     19.89     46.333333
#
#    Temp_living  Humidity_living  Temp_laundry  Humidity_laundry  Temp_office  \
# 0         19.2        44.790000         19.79         44.730000    19.000000
# 1         19.2        44.722500         19.79         44.790000    19.000000
# 2         19.2        44.626667         19.79         44.933333    18.926667
# 3         19.2        44.590000         19.79         45.000000    18.890000
# 4         19.2        44.530000         19.79         45.000000    18.890000
#
#    ...  Temp_parents  Humidity_parents  Temp_outside  press_mm_hg  \
# ...

# %%
df.columns = df.columns.str.lower()

# %%
df.head()
# Out:
#                   date  appliances  lights  temp_kit  humidity_kit  \
# 0  2016-01-11 17:00:00          60      30     19.89     47.596667
# 1  2016-01-11 17:10:00          60      30     19.89     46.693333
# 2  2016-01-11 17:20:00          50      30     19.89     46.300000
# 3  2016-01-11 17:30:00          50      40     19.89     46.066667
# 4  2016-01-11 17:40:00          60      40     19.89     46.333333
#
#    temp_living  humidity_living  temp_laundry  humidity_laundry  temp_office  \
# 0         19.2        44.790000         19.79         44.730000    19.000000
# 1         19.2        44.722500         19.79         44.790000    19.000000
# 2         19.2        44.626667         19.79         44.933333    18.926667
# 3         19.2        44.590000         19.79         45.000000    18.890000
# 4         19.2        44.530000         19.79         45.000000    18.890000
#
#    ...  temp_parents  humidity_parents  temp_outside  press_mm_hg  \
# ...

# %%
#select a sample of the dataset
simple_linear_reg_df = df[['temp_living', 'temp_outbuilding']].sample(15, random_state = 2)

# %%
simple_linear_reg_df
# Out:
#        temp_living  temp_outbuilding
# 1117     17.426667         -4.238889
# 16275    22.760000         14.690000
# 13272    21.230000          8.926667
# 3160     21.100000          7.690000
# 19210    21.856667         10.800000
# 8260     17.356667          5.000000
# 12299    19.000000          5.300000
# 13505    22.700000         17.133333
# 12913    19.593333          7.545000
# 17788    21.890000          9.190000
# 17894    21.500000          5.160000
# 7665     19.142857          0.937500
# 10165    18.000000          0.200000
# 18809    22.400000         16.833333
# 8737     17.066667          1.900000

# %%
sns.regplot(x = "temp_living", y = "temp_outbuilding", data = simple_linear_reg_df)
# Out:
# <AxesSubplot:xlabel='temp_living', ylabel='temp_outbuilding'>

# %%
#Firstly normalise dataset to a common scale using the min max scaler
from sklearn.preprocessing import MinMaxScaler

# %%
features_df = df.drop(columns = ['date', 'lights', 'appliances'])
scaler = MinMaxScaler()
heading_target = df['appliances']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features_df, heading_target, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
#fit the model to the training dataset
linear_model.fit(x_train, y_train)
#obtain predictions
predicted_values = linear_model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predicted_values)
round(mae, 3)
# Out:
# 66.522

# %% [markdown]
# # R Squared

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values)
round(r2_score, 3)
# Out:
# -0.154

# %% [markdown]
# #Residual Sum of Squares

# %%
import numpy as np
rss = np.sum(np.square(y_test - predicted_values))
round(rss, 3)
# Out:
# 70397387.564

# %% [raw]
# #Root Mean Square Error

# %%
from sklearn.metrics import  mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 3)
# Out:
# 109.039

# %%
def get_weights_df(model, feat, col_name):
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha = 0.4)
ridge_reg.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.4)

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha = 0.001)
lasso_reg.fit(x_train, y_train)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6136226.882462382, tolerance: 14642.917148544939
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=0.001)
